# %% [markdown]
# # Holistic Technical Evaluation: Output Experiments 700-1259
#
# Generated: 2026-06-17.
#
# This notebook evaluates the coordinate-optimizer experiment archive from output
# experiment IDs `700` through `1259`. The scope includes
# `560` numbered output folders and `442` parseable
# coordinate-optimizer runs with confidence CSV files.
#
# The goal is not to repeat each individual run report. It is to show how groups
# of experiments support decisions: when a source-density ladder works, when a
# transmitter/receiver spacing probe works, and where a branch should stop.
#
# Noncanonical-primary objective runs excluded from base-policy charts and series: `1`.

# %% [markdown]
# ## Terms Used In This Notebook
#
# - Ground-penetrating radar (GPR): the simulated radar measurement modality.
# - Full-waveform inversion (FWI): an inverse method that compares simulated and
#   observed waveforms to recover rebar geometry.
# - Coordinate optimizer: the search routine that tests candidate rebar
#   coordinates and radii, then selects the candidate with the best score.
# - Objective, or objective function: the scoring rule used to compare a
#   candidate model against the reference data. In this archive the score is a
#   waveform mismatch, also called a misfit. Lower misfit is better. When the
#   report says a candidate "wins" an objective, it means that candidate produced
#   the smallest mismatch under that scoring rule.
# - Base objective: the main/default scoring rule used for the acceptance
#   decision.
# - Objective variants: diagnostic scoring rules that use different signal
#   windows or frequency bands, such as late-time or high-frequency content.
#   They are not separate experiments; they are alternate checks on the same
#   run. Agreement across variants gives stronger evidence than the base
#   objective alone.
# - Target rebar: the specific rebar being evaluated in a run. The synthetic
#   three-rebar geometry used here is fixed unless stated otherwise.
# - `target0`: the shallow-left rebar, x=150 mm, z=80 mm, radius=5 mm.
# - `target1`: the center rebar, x=250 mm, z=100 mm, radius=6 mm.
# - `target2`: the deeper-right rebar, x=350 mm, z=120 mm, radius=8 mm.
# - Tx/Rx offset: transmitter-to-receiver spacing in millimeters.
# - Source-density ladder: rerunning the same target with more source positions,
#   for example 5, 7, 9, or 11 sources.
# - Acquisition-offset bracket: rerunning the same target at different Tx/Rx
#   offsets, for example 60, 52.5, 50, and 45 mm.
# - `seed...`: the pseudo-random seed controlling the repeatable synthetic
#   noise/source-mismatch draw. It is not a different physical rebar geometry.
#   Unless explicitly stated, the true rebar geometry remains x=[150, 250, 350]
#   mm, z=[80, 100, 120] mm, radius=[5, 6, 8] mm.
# - Base margin: the gap, under the base objective, between the selected radius
#   and the next-best competing radius. A larger margin means the radius choice
#   is more clearly separated from the alternative. The strict
#   moderate-confidence cutoff used here is 5.0e-4.
# - Exact geometry: the selected x position, z depth, and radius match the known
#   synthetic truth. Several weak rows still have exact geometry; they are weak
#   because the confidence margin is small, not because the location is wrong.
# - Accepted row: a run whose base margin is at or above 5.0e-4.
# - Weak row: a run whose base margin is below 5.0e-4.

# %%
# This notebook is generated by run_experiment_700_1218_holistic_report.py.
# The supporting tables are in:
# outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/data
import pandas as pd
run_summary = pd.read_csv("../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/data/coordinate_run_summary_700_1259.csv")
series_summary = pd.read_csv("../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/data/series_summary_700_1259.csv")
run_summary.head()

# %% [markdown]
# ## Archive-Level Summary
#
# Across the `442` parseable coordinate-optimizer runs:
#
# - `433` runs preserve the exact final x/z/r geometry.
# - `275` runs clear the strict base-margin cutoff.
# - `167` runs remain below the strict base-margin cutoff.
# - The weak rows are mostly radius-confidence limitations, not localization
#   failures, because the selected geometry usually remains exact and diagnostic
#   scoring variants often rank the true geometry first.
#
# ![Base margin by output experiment ID](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/overview_margin_by_run.png)
#
# *Figure: Each point is one parseable coordinate-optimizer run. The dashed line is the strict 5.0e-4 base-margin cutoff; points below it are exact-geometry rows whose radius confidence is still too weak.*
#
# ![Acceptance rate by target](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/acceptance_rate_by_target.png)
#
# *Figure: The bars show the fraction of rows for each target rebar that clear the strict cutoff. This separates target-specific confidence behavior from overall archive size.*
#
# ![Margin distribution by target](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/margin_distribution_by_target.png)
#
# *Figure: The boxes summarize base-margin spread for each target rebar. A target with many values close to the dashed cutoff is sensitive to acquisition settings or scoring-rule changes.*
#
# ![Phase coverage](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/phase_coverage.png)
#
# *Figure: This horizontal bar chart shows how many parseable coordinate-optimizer runs came from each experiment phase, so later conclusions can be tied back to run coverage.*
#
# ![Detected series counts](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/detected_series_counts.png)
#
# *Figure: The bars count automatically detected multi-run series by intervention family: source density, Tx/Rx offset, and ringdown parameter.*
#
# ![Seed branch grid](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/seed_branch_best_margin_grid.png)
#
# *Figure: Each cell shows the best base margin and run ID for a seed-target branch in the later ringdown050 replication block. It is a compact map of which branches remained close to the cutoff.*

# %% [markdown]
# ## Phase Table
#
# | Phase | First run | Last run | Runs | Accepted fraction | Median margin |
# | --- | --- | --- | --- | --- | --- |
# | Tx/Rx and receiver-sampling diagnostics | 740 | 783 | 31 | 0.645 | 5.439e-04 |
# | source-density and ringdown diagnostics | 784 | 848 | 54 | 0.704 | 5.304e-04 |
# | ringdown050 replication and rescue-policy development | 849 | 1118 | 241 | 0.602 | 5.096e-04 |
# | extended ringdown050 replication and stop-point block | 1120 | 1257 | 116 | 0.621 | 5.177e-04 |

# %% [markdown]
# ## Main Conclusions From The Grouped Experiments
#
# 1. Exact geometry recovery is robust in this archive. The harder problem is
#    radius-confidence separation against the next candidate radius.
# 2. Target0 weak rows are often acquisition-sensitive. The Tx/Rx offset bracket
#    repeatedly improves confidence, especially when moving from 60 mm toward
#    52.5, 50, or 45 mm.
# 3. Target2 weak rows are often source-density-sensitive. The 5/7/9 source
#    ladder repeatedly converts exact-but-weak rows into accepted rows.
# 4. Target1 weak rows are mixed. Some seeds are rescued cleanly by 9 sources,
#    while seed5527939710754757 worsens at 11 sources. That is a policy signal:
#    do not keep increasing source density blindly.

# %% [markdown]
# ## Policy Synthesis Increment
#
# This section compresses the `123` detected multi-run series into
# intervention evidence. An intervention means a controlled rerun that changes
# one acquisition or modeling setting while keeping the synthetic rebar geometry
# fixed.
#
# The key caution is that these are not independent laboratory measurements:
# several rows share the same seed, target, and run family. The plots are still
# useful because they show which intervention types repeatedly changed the
# radius-confidence margin enough to matter.
#
# ![Intervention outcome counts](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/intervention_outcome_counts.png)
#
# *Figure: Stacked bars count whether each detected intervention series was always accepted, always weak, or mixed with at least one accepted setting. This summarizes which intervention families most often produced usable confidence.*
#
# ![Intervention margin spread](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/intervention_margin_spread.png)
#
# *Figure: Each distribution shows the within-series gap between the best and worst tested setting. Larger spreads mean the intervention can materially change the radius-confidence decision.*
#
# Outcome counts by intervention family:
#
# | Series type | All accepted | Mixed with accepted setting | All weak |
# | --- | --- | --- | --- |
# | ringdown | 12 | 5 | 5 |
# | source_density | 2 | 47 | 13 |
# | tx_rx_offset | 8 | 18 | 13 |
#
# Largest within-series margin movements:
#
# | Type | Runs | Seed | Target | Varied | Best run | Best setting | Best margin | Worst run | Worst setting | Worst margin | Spread | Outcome |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | ringdown | 791, 869 | 89 | 2 | ringdown_value | 791 | 0.250 | 5.243e-04 | 869 | 0.500 | 4.605e-04 | 6.384e-05 | mixed: accepted setting exists |
# | ringdown | 786, 792, 793, 794, 819 | 89 | 1 | ringdown_value | 794 | 0.350 | 5.425e-04 | 793 | 0.250 | 4.841e-04 | 5.834e-05 | mixed: accepted setting exists |
# | ringdown | 789, 795, 823, 842 | 89 | 0 | ringdown_value | 795 | 0.350 | 5.955e-04 | 842 | 0.500 | 5.460e-04 | 4.944e-05 | all accepted |
# | ringdown | 783, 868 | 89 | 2 | ringdown_value | 783 | 0.250 | 5.101e-04 | 868 | 0.500 | 4.616e-04 | 4.843e-05 | mixed: accepted setting exists |
# | ringdown | 802, 826, 846, 848, 849, 852, 853, 854, 855, 856 | 21 | 0 | ringdown_value | 802 | 0.350 | 5.445e-04 | 846 | 0.500 | 4.975e-04 | 4.697e-05 | mixed: accepted setting exists |
# | ringdown | 745, 750 | 89 | 2 | ringdown_value | 750 | 0.350 | 1.039e-03 | 745 | 0.250 | 9.936e-04 | 4.529e-05 | all accepted |
# | ringdown | 805, 817, 840 | 13 | 0 | ringdown_value | 805 | 0.350 | 6.075e-04 | 840 | 0.500 | 5.626e-04 | 4.490e-05 | all accepted |
# | ringdown | 744, 751 | 89 | 0 | ringdown_value | 751 | 0.350 | 6.142e-04 | 744 | 0.250 | 5.798e-04 | 3.436e-05 | all accepted |
# | ringdown | 788, 797 | 89 | 0 | ringdown_value | 797 | 0.350 | 4.975e-04 | 788 | 0.250 | 4.631e-04 | 3.434e-05 | all weak |
# | ringdown | 746, 749 | 89 | 1 | ringdown_value | 749 | 0.350 | 6.281e-04 | 746 | 0.250 | 5.983e-04 | 2.980e-05 | all accepted |
# | ringdown | 889, 891, 892, 893, 894, 895, 896 | 610 | 2 | ringdown_value | 894 | 0.400 | 4.969e-04 | 896 | 0.250 | 4.678e-04 | 2.914e-05 | all weak |
# | ringdown | 787, 796, 822, 844 | 89 | 2 | ringdown_value | 796 | 0.350 | 6.059e-04 | 787 | 0.250 | 5.780e-04 | 2.786e-05 | all accepted |
# | ringdown | 754, 835 | 89 | 1 | ringdown_value | 835 | 0.500 | 5.591e-04 | 754 | 0.250 | 5.319e-04 | 2.715e-05 | all accepted |
# | ringdown | 806, 809, 810, 811, 812, 813, 814 | 13 | 1 | ringdown_value | 806 | 0.350 | 5.109e-04 | 810 | 0.500 | 4.879e-04 | 2.299e-05 | mixed: accepted setting exists |
# | ringdown | 804, 825, 850, 864 | 21 | 2 | ringdown_value | 804 | 0.350 | 5.338e-04 | 864 | 0.495 | 5.149e-04 | 1.893e-05 | all accepted |
# | ringdown | 765, 779 | 89 | 2 | ringdown_value | 779 | 0.350 | 4.945e-04 | 765 | 0.250 | 4.769e-04 | 1.758e-05 | all weak |
# | ringdown | 829, 830, 831, 832, 834 | 13 | 1 | ringdown_value | 829 | 0.459 | 5.428e-04 | 834 | 0.500 | 5.294e-04 | 1.337e-05 | all accepted |
# | ringdown | 780, 782 | 89 | 2 | ringdown_value | 780 | 0.250 | 6.453e-04 | 782 | 0.350 | 6.320e-04 | 1.333e-05 | all accepted |

# %% [markdown]
# ## Source Count And Tx/Rx Evidence
#
# Source count is the number of transmitter source positions used for the
# synthetic survey. Tx/Rx offset is the transmitter-to-receiver spacing in
# millimeters. The median plots below are aggregate summaries, so individual
# seed-level examples should still be checked before choosing a new marathon
# branch.
#
# ![Source-count policy evidence](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/source_count_by_target_policy.png)
#
# *Figure: The top panel shows median base margin versus number of source positions for each target; the lower panel shows the percentage clearing the cutoff. This distinguishes source-count settings that improve confidence from settings that add cost without reliable benefit.*
#
# Source-count summary:
#
# | Target | Sources | Runs | Accepted fraction | Median margin | First run | Last run |
# | --- | --- | --- | --- | --- | --- | --- |
# | 0 | 5 | 6 | 1.000 | 5.588e-04 | 740 | 839 |
# | 0 | 7 | 2 | 0.500 | 5.052e-04 | 784 | 858 |
# | 0 | 8 | 107 | 0.710 | 5.150e-04 | 789 | 1214 |
# | 0 | 9 | 15 | 0.467 | 4.975e-04 | 788 | 1140 |
# | 0 | 11 | 3 | 0.333 | 4.500e-04 | 951 | 1026 |
# | 0 | 15 | 1 | 0.000e+00 | 4.522e-04 | 801 | 801 |
# | 1 | 5 | 101 | 0.723 | 5.294e-04 | 742 | 1240 |
# | 1 | 7 | 2 | 0.000e+00 | 3.936e-04 | 785 | 998 |
# | 1 | 8 | 3 | 0.000e+00 | 4.925e-04 | 790 | 899 |
# | 1 | 9 | 25 | 0.680 | 5.084e-04 | 786 | 1217 |
# | 1 | 11 | 2 | 0.000e+00 | 3.774e-04 | 984 | 1218 |
# | 2 | 4 | 9 | 0.889 | 1.632e-03 | 1219 | 1257 |
# | 2 | 5 | 90 | 0.556 | 5.096e-04 | 741 | 1226 |
# | 2 | 7 | 25 | 0.320 | 4.743e-04 | 780 | 1208 |
# | 2 | 8 | 3 | 0.333 | 4.722e-04 | 791 | 869 |
# | 2 | 9 | 42 | 0.643 | 5.167e-04 | 781 | 1209 |
# | 2 | 11 | 6 | 0.000e+00 | 4.002e-04 | 890 | 1153 |
#
# ![Tx/Rx policy evidence](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/txrx_offset_by_target_policy.png)
#
# *Figure: Each panel shows individual run margins and median margins by transmitter/receiver spacing for one target. Offsets whose medians move above the dashed cutoff are acquisition settings worth reusing.*
#
# Tx/Rx summary for offsets with at least two runs:
#
# | Target | Tx/Rx mm | Runs | Accepted fraction | Median margin | First run | Last run |
# | --- | --- | --- | --- | --- | --- | --- |
# | 0 | 45.000 | 4 | 0.750 | 5.216e-04 | 1011 | 1214 |
# | 0 | 50.000 | 7 | 0.857 | 5.105e-04 | 740 | 1213 |
# | 0 | 52.500 | 14 | 0.571 | 5.031e-04 | 992 | 1212 |
# | 0 | 60.000 | 107 | 0.682 | 5.180e-04 | 756 | 1211 |
# | 1 | 50.000 | 6 | 0.667 | 5.520e-04 | 742 | 1234 |
# | 1 | 52.500 | 14 | 0.643 | 5.062e-04 | 991 | 1224 |
# | 1 | 55.000 | 4 | 0.250 | 4.758e-04 | 989 | 1240 |
# | 1 | 57.500 | 2 | 0.000e+00 | 4.876e-04 | 990 | 1236 |
# | 1 | 60.000 | 105 | 0.714 | 5.255e-04 | 754 | 1218 |
# | 2 | 25.000 | 2 | 0.500 | 4.314e-04 | 1219 | 1221 |
# | 2 | 50.000 | 12 | 0.917 | 1.592e-03 | 741 | 1257 |
# | 2 | 50.039 | 2 | 0.500 | 5.273e-04 | 769 | 771 |
# | 2 | 50.312 | 7 | 0.714 | 5.779e-04 | 765 | 782 |
# | 2 | 52.500 | 3 | 0.333 | 4.859e-04 | 761 | 1001 |
# | 2 | 60.000 | 142 | 0.528 | 5.044e-04 | 755 | 1215 |

# %% [markdown]
# ## Target1 Source-Density Stop Point
#
# Target1 is the center rebar. Its source-density branches are important because
# they include both clean rescues and unresolved exact-geometry runs. The figure
# draws a line from the worst to best margin within each target1 source-density
# series; the vertical dashed line is the strict 5.0e-4 cutoff.
#
# ![Target1 source-density rescue map](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/target1_source_density_rescue_map.png)
#
# *Figure: Each horizontal line spans the worst-to-best margin within one target1 source-density series. Green or mixed outcomes show branches where a tested source count cleared the cutoff; red unresolved lines show branches where more sources did not solve confidence.*
#
# Target1 source-density series:
#
# | Runs | Seed | Runs in series | Accepted | Best run | Best sources | Best margin | Worst run | Worst sources | Worst margin | Outcome |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 754, 785, 786, 790, 792, 793 | 89 | 6 | 2 | 754 | 5.000 | 5.319e-04 | 785 | 7.000 | 3.489e-04 | mixed: accepted setting exists |
# | 794, 798 | 89 | 2 | 1 | 794 | 9.000 | 5.425e-04 | 798 | 8.000 | 4.925e-04 | mixed: accepted setting exists |
# | 810, 834 | 13 | 2 | 1 | 834 | 5.000 | 5.294e-04 | 810 | 9.000 | 4.879e-04 | mixed: accepted setting exists |
# | 811, 832 | 13 | 2 | 1 | 832 | 5.000 | 5.382e-04 | 811 | 9.000 | 4.963e-04 | mixed: accepted setting exists |
# | 812, 830 | 13 | 2 | 1 | 830 | 5.000 | 5.419e-04 | 812 | 9.000 | 4.999e-04 | mixed: accepted setting exists |
# | 814, 829 | 13 | 2 | 2 | 829 | 5.000 | 5.428e-04 | 814 | 9.000 | 5.007e-04 | all accepted |
# | 897, 898, 899 | 610 | 3 | 0 | 897 | 5.000 | 4.677e-04 | 898 | 9.000 | 4.198e-04 | all weak |
# | 907, 908 | 1597 | 2 | 1 | 908 | 9.000 | 5.127e-04 | 907 | 5.000 | 4.919e-04 | mixed: accepted setting exists |
# | 955, 956 | 196418 | 2 | 1 | 956 | 9.000 | 5.896e-04 | 955 | 5.000 | 4.809e-04 | mixed: accepted setting exists |
# | 970, 971 | 832040 | 2 | 1 | 971 | 9.000 | 5.167e-04 | 970 | 5.000 | 3.952e-04 | mixed: accepted setting exists |
# | 982, 983, 984 | 2178309 | 3 | 0 | 982 | 5.000 | 4.821e-04 | 984 | 11.000 | 3.915e-04 | all weak |
# | 995, 998, 999 | 832040 | 3 | 1 | 999 | 9.000 | 5.297e-04 | 995 | 5.000 | 4.179e-04 | mixed: accepted setting exists |
# | 1057, 1058 | 267914296 | 2 | 1 | 1058 | 9.000 | 5.080e-04 | 1057 | 5.000 | 4.895e-04 | mixed: accepted setting exists |
# | 1114, 1115 | 139583862445 | 2 | 1 | 1115 | 9.000 | 5.084e-04 | 1114 | 5.000 | 4.811e-04 | mixed: accepted setting exists |
# | 1159, 1160 | 17167680207565 | 2 | 1 | 1160 | 9.000 | 5.549e-04 | 1159 | 5.000 | 4.758e-04 | mixed: accepted setting exists |
# | 1172, 1173 | 72723460378141 | 2 | 1 | 1173 | 9.000 | 5.446e-04 | 1172 | 5.000 | 4.343e-04 | mixed: accepted setting exists |
# | 1216, 1217, 1218 | 5527939710754757 | 3 | 0 | 1217 | 9.000 | 4.875e-04 | 1218 | 11.000 | 3.632e-04 | all weak |

# %% [markdown]
# ## Curated Series Deep Dives

# %% [markdown]
# ### Seed5527939710754757 target1 source-density rescue did not resolve radius confidence
#
# Runs: `1216, 1217, 1218`.
#
# The exact target1 geometry is preserved, but base margin rises at 9 sources and then drops at 11 sources. This supports stopping the source-density ladder.
#
# ![Seed5527939710754757 target1 source-density rescue did not resolve radius confidence](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/curated_seed5527939710754757_target1_sources_1216_1218.png)
#
# *Figure: The upper panel compares base margins across runs 1216, 1217, 1218; the dashed line is the strict cutoff. The lower heatmap shows radius margins under several scoring-rule variants, also called objective variants. If several rows in the heatmap are strong, the conclusion is supported by more than the default base scoring rule. The exact target1 geometry is preserved, but base margin rises at 9 sources and then drops at 11 sources. This supports stopping the source-density ladder.*
#
# | Run | Target | Sources | Tx/Rx mm | Ringdown | Base margin | Label | Fallback | Exact geometry |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1216 | 1 | 5 | 60.000 | 050 | 4.516e-04 | weak | radius_weak_confidence | True |
# | 1217 | 1 | 9 | 60.000 | 050 | 4.875e-04 | weak | radius_weak_confidence | True |
# | 1218 | 1 | 11 | 60.000 | 050 | 3.632e-04 | weak | radius_weak_confidence | True |

# %% [markdown]
# ### Seed5527939710754757 target0 Tx/Rx acquisition bracket found a stronger lower offset
#
# Runs: `1211, 1212, 1213, 1214`.
#
# Target0 base margin improves as Tx/Rx offset is reduced from 60 to 45 mm, making 45 mm the strongest tested point for this seed.
#
# ![Seed5527939710754757 target0 Tx/Rx acquisition bracket found a stronger lower offset](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/curated_seed5527939710754757_target0_txrx_1211_1214.png)
#
# *Figure: The upper panel compares base margins across runs 1211, 1212, 1213, 1214; the dashed line is the strict cutoff. The lower heatmap shows radius margins under several scoring-rule variants, also called objective variants. If several rows in the heatmap are strong, the conclusion is supported by more than the default base scoring rule. Target0 base margin improves as Tx/Rx offset is reduced from 60 to 45 mm, making 45 mm the strongest tested point for this seed.*
#
# | Run | Target | Sources | Tx/Rx mm | Ringdown | Base margin | Label | Fallback | Exact geometry |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1211 | 0 | 8 | 60.000 | 050 | 4.505e-04 | weak | radius_weak_confidence | True |
# | 1212 | 0 | 8 | 52.500 | 050 | 4.930e-04 | weak | radius_weak_confidence | True |
# | 1213 | 0 | 8 | 50.000 | 050 | 5.024e-04 | moderate |  | True |
# | 1214 | 0 | 8 | 45.000 | 050 | 5.150e-04 | moderate |  | True |

# %% [markdown]
# ### Seed3416454629006707 target2 source-density ladder rescued a weak control
#
# Runs: `1207, 1208, 1209`.
#
# Target2 is weak at 5 and 7 sources but crosses the base cutoff at 9 sources, supporting the 5/7/9 source-density ladder for this target.
#
# ![Seed3416454629006707 target2 source-density ladder rescued a weak control](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/curated_seed3416454629006707_target2_sources_1207_1209.png)
#
# *Figure: The upper panel compares base margins across runs 1207, 1208, 1209; the dashed line is the strict cutoff. The lower heatmap shows radius margins under several scoring-rule variants, also called objective variants. If several rows in the heatmap are strong, the conclusion is supported by more than the default base scoring rule. Target2 is weak at 5 and 7 sources but crosses the base cutoff at 9 sources, supporting the 5/7/9 source-density ladder for this target.*
#
# | Run | Target | Sources | Tx/Rx mm | Ringdown | Base margin | Label | Fallback | Exact geometry |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1207 | 2 | 5 | 60.000 | 050 | 4.242e-04 | weak | radius_weak_confidence | True |
# | 1208 | 2 | 7 | 60.000 | 050 | 4.936e-04 | weak | radius_weak_confidence | True |
# | 1209 | 2 | 9 | 60.000 | 050 | 5.601e-04 | moderate |  | True |

# %% [markdown]
# ### Seed2111485081748050 target2 7-source bracket rescued a near-miss control
#
# Runs: `1203, 1204`.
#
# The 5-source target2 run is a near-miss, and the 7-source bracket clears the strict base-margin cutoff without a 9-source escalation.
#
# ![Seed2111485081748050 target2 7-source bracket rescued a near-miss control](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/curated_seed2111485081748050_target2_sources_1203_1204.png)
#
# *Figure: The upper panel compares base margins across runs 1203, 1204; the dashed line is the strict cutoff. The lower heatmap shows radius margins under several scoring-rule variants, also called objective variants. If several rows in the heatmap are strong, the conclusion is supported by more than the default base scoring rule. The 5-source target2 run is a near-miss, and the 7-source bracket clears the strict base-margin cutoff without a 9-source escalation.*
#
# | Run | Target | Sources | Tx/Rx mm | Ringdown | Base margin | Label | Fallback | Exact geometry |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1203 | 2 | 5 | 60.000 | 050 | 4.994e-04 | weak | radius_weak_confidence | True |
# | 1204 | 2 | 7 | 60.000 | 050 | 5.313e-04 | moderate |  | True |

# %% [markdown]
# ### Seed365435296162 target0 Tx/Rx bracket established the lower-offset rescue pattern
#
# Runs: `1120, 1121, 1122, 1123`.
#
# This earlier bracket shows the same target0 behavior: lowering Tx/Rx offset turns a weak exact row into an accepted row with better reserve.
#
# ![Seed365435296162 target0 Tx/Rx bracket established the lower-offset rescue pattern](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/curated_seed365435296162_target0_txrx_1120_1123.png)
#
# *Figure: The upper panel compares base margins across runs 1120, 1121, 1122, 1123; the dashed line is the strict cutoff. The lower heatmap shows radius margins under several scoring-rule variants, also called objective variants. If several rows in the heatmap are strong, the conclusion is supported by more than the default base scoring rule. This earlier bracket shows the same target0 behavior: lowering Tx/Rx offset turns a weak exact row into an accepted row with better reserve.*
#
# | Run | Target | Sources | Tx/Rx mm | Ringdown | Base margin | Label | Fallback | Exact geometry |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1120 | 0 | 8 | 60.000 | 050 | 4.624e-04 | weak | radius_weak_confidence | True |
# | 1121 | 0 | 8 | 52.500 | 050 | 4.943e-04 | weak | radius_weak_confidence | True |
# | 1122 | 0 | 8 | 50.000 | 050 | 5.050e-04 | moderate |  | True |
# | 1123 | 0 | 8 | 45.000 | 050 | 5.282e-04 | moderate |  | True |

# %% [markdown]
# ### Seed139583862445 target1 9-source rescue converted a weak control
#
# Runs: `1114, 1115`.
#
# A 9-source target1 rescue can work: the weak 5-source row becomes accepted and all objective variants rank the true geometry.
#
# ![Seed139583862445 target1 9-source rescue converted a weak control](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/curated_seed139583862445_target1_sources_1114_1115.png)
#
# *Figure: The upper panel compares base margins across runs 1114, 1115; the dashed line is the strict cutoff. The lower heatmap shows radius margins under several scoring-rule variants, also called objective variants. If several rows in the heatmap are strong, the conclusion is supported by more than the default base scoring rule. A 9-source target1 rescue can work: the weak 5-source row becomes accepted and all objective variants rank the true geometry.*
#
# | Run | Target | Sources | Tx/Rx mm | Ringdown | Base margin | Label | Fallback | Exact geometry |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1114 | 1 | 5 | 60.000 | 050 | 4.811e-04 | weak | radius_weak_confidence | True |
# | 1115 | 1 | 9 | 60.000 | 050 | 5.084e-04 | moderate |  | True |

# %% [markdown]
# ### Seed72723460378141 target1 9-source rescue produced a clean acceptance
#
# Runs: `1172, 1173`.
#
# This branch is a clean target1 rescue example, contrasting with the later seed5527939710754757 unresolved branch.
#
# ![Seed72723460378141 target1 9-source rescue produced a clean acceptance](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/curated_seed72723460378141_target1_sources_1172_1173.png)
#
# *Figure: The upper panel compares base margins across runs 1172, 1173; the dashed line is the strict cutoff. The lower heatmap shows radius margins under several scoring-rule variants, also called objective variants. If several rows in the heatmap are strong, the conclusion is supported by more than the default base scoring rule. This branch is a clean target1 rescue example, contrasting with the later seed5527939710754757 unresolved branch.*
#
# | Run | Target | Sources | Tx/Rx mm | Ringdown | Base margin | Label | Fallback | Exact geometry |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1172 | 1 | 5 | 60.000 | 050 | 4.343e-04 | weak | radius_weak_confidence | True |
# | 1173 | 1 | 9 | 60.000 | 050 | 5.446e-04 | moderate |  | True |

# %% [markdown]
# ### Seed89 target2 Tx/Rx threshold and linear-receiver sensitivity
#
# Runs: `759, 760, 761, 762, 763, 765, 766, 767, 769`.
#
# The target2 confidence drop around 50-60 mm Tx/Rx offset motivated later acquisition and receiver-sampling checks.
#
# ![Seed89 target2 Tx/Rx threshold and linear-receiver sensitivity](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/curated_seed89_target2_txrx_threshold_759_769.png)
#
# *Figure: The upper panel compares base margins across runs 759, 760, 761, 762, 763, 765, 766, 767, 769; the dashed line is the strict cutoff. The lower heatmap shows radius margins under several scoring-rule variants, also called objective variants. If several rows in the heatmap are strong, the conclusion is supported by more than the default base scoring rule. The target2 confidence drop around 50-60 mm Tx/Rx offset motivated later acquisition and receiver-sampling checks.*
#
# | Run | Target | Sources | Tx/Rx mm | Ringdown | Base margin | Label | Fallback | Exact geometry |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 759 | 2 | 5 | 60.000 | 025 | 4.330e-04 | weak | radius_weak_confidence | True |
# | 760 | 2 | 5 | 55.000 | 025 | 4.605e-04 | weak | radius_weak_confidence | True |
# | 761 | 2 | 5 | 52.500 | 025 | 4.725e-04 | weak | radius_weak_confidence | True |
# | 762 | 2 | 5 | 51.250 | 025 | 4.753e-04 | weak | radius_weak_confidence | True |
# | 763 | 2 | 5 | 50.625 | 025 | 4.753e-04 | weak | radius_weak_confidence | True |
# | 765 | 2 | 5 | 50.312 | 025 | 4.769e-04 | weak | radius_weak_confidence | True |
# | 766 | 2 | 5 | 50.156 | 025 | 4.773e-04 | weak | radius_weak_confidence | True |
# | 767 | 2 | 5 | 50.078 | 025 | 4.774e-04 | weak | radius_weak_confidence | True |
# | 769 | 2 | 5 | 50.039 | 025 | 4.775e-04 | weak | radius_weak_confidence | True |

# %% [markdown]
# ## Automatically Detected Series Index
#
# The table below is the systematic index of multi-run series detected from
# output experiment IDs {RUN_MIN}-{RUN_MAX}. Each row has a corresponding plot in the
# appendix and a CSV row in `{ranged_csv_name('series_summary')}`.
#
#
# | Type | Runs | Seed | Target | Varied | Values | Best run | Best margin | Conclusion |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | ringdown | 746, 749 | 89 | 1 | ringdown_value | 0.25, 0.35 | 749 | 6.281e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 749. |
# | ringdown | 745, 750 | 89 | 2 | ringdown_value | 0.25, 0.35 | 750 | 1.039e-03 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 750. |
# | ringdown | 744, 751 | 89 | 0 | ringdown_value | 0.25, 0.35 | 751 | 6.142e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 751. |
# | ringdown | 765, 779 | 89 | 2 | ringdown_value | 0.25, 0.35 | 779 | 4.945e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 779. |
# | ringdown | 780, 782 | 89 | 2 | ringdown_value | 0.25, 0.35 | 780 | 6.453e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 780. |
# | ringdown | 783, 868 | 89 | 2 | ringdown_value | 0.25, 0.5 | 783 | 5.101e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 783. |
# | ringdown | 790, 798 | 89 | 1 | ringdown_value | 0.25, 0.35 | 790 | 4.999e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 790. |
# | ringdown | 791, 869 | 89 | 2 | ringdown_value | 0.25, 0.5 | 791 | 5.243e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 791. |
# | ringdown | 786, 792, 793, 794, 819 | 89 | 1 | ringdown_value | 0.25, 0.25, 0.25, 0.35, 0.459375 | 794 | 5.425e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 794. |
# | ringdown | 789, 795, 823, 842 | 89 | 0 | ringdown_value | 0.25, 0.35, 0.459375, 0.5 | 795 | 5.955e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 795. |
# | ringdown | 787, 796, 822, 844 | 89 | 2 | ringdown_value | 0.25, 0.35, 0.459375, 0.5 | 796 | 6.059e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 796. |
# | ringdown | 788, 797 | 89 | 0 | ringdown_value | 0.25, 0.35 | 797 | 4.975e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 797. |
# | ringdown | 802, 826, 846, 848, 849, 852, 853, 854, 855, 856 | 21 | 0 | ringdown_value | 0.35, 0.459375, 0.5, 0.475, 0.49375, 0.496875, 0.4953125, 0.49453125, 0.494921875, 0.4947265625 | 802 | 5.445e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 802. |
# | ringdown | 803, 820 | 21 | 1 | ringdown_value | 0.35, 0.459375 | 803 | 5.683e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 803. |
# | ringdown | 804, 825, 850, 864 | 21 | 2 | ringdown_value | 0.35, 0.459375, 0.49375, 0.49453125 | 804 | 5.338e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 804. |
# | ringdown | 805, 817, 840 | 13 | 0 | ringdown_value | 0.35, 0.459375, 0.5 | 805 | 6.075e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 805. |
# | ringdown | 806, 809, 810, 811, 812, 813, 814 | 13 | 1 | ringdown_value | 0.35, 0.45, 0.5, 0.475, 0.4625, 0.45625, 0.459375 | 806 | 5.109e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 806. |
# | ringdown | 807, 816 | 13 | 2 | ringdown_value | 0.35, 0.459375 | 807 | 5.646e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 807. |
# | ringdown | 829, 830, 831, 832, 834 | 13 | 1 | ringdown_value | 0.459375, 0.4625, 0.46875, 0.475, 0.5 | 829 | 5.428e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 829. |
# | ringdown | 754, 835 | 89 | 1 | ringdown_value | 0.25, 0.5 | 835 | 5.591e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 835. |
# | ringdown | 755, 759, 843 | 89 | 2 | ringdown_value | 0.25, 0.25, 0.5 | 843 | 4.415e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 843. |
# | ringdown | 889, 891, 892, 893, 894, 895, 896 | 610 | 2 | ringdown_value | 0.5, 0.49453125, 0.475, 0.459375, 0.4, 0.35, 0.25 | 894 | 4.969e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 894. |
# | source_density | 754, 785, 786, 790, 792, 793 | 89 | 1 | sources | 5, 7, 9, 8, 9, 9 | 754 | 5.319e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 754. |
# | source_density | 765, 780, 781 | 89 | 2 | sources | 5, 7, 9 | 780 | 6.453e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 780. |
# | source_density | 779, 782 | 89 | 2 | sources | 5, 7 | 782 | 6.320e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 782. |
# | source_density | 755, 759, 783, 787, 791 | 89 | 2 | sources | 5, 5, 7, 9, 8 | 787 | 5.780e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 787. |
# | source_density | 756, 784, 788, 789 | 89 | 0 | sources | 5, 7, 9, 8 | 789 | 5.900e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 789. |
# | source_density | 794, 798 | 89 | 1 | sources | 9, 8 | 794 | 5.425e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 794. |
# | source_density | 795, 797, 801 | 89 | 0 | sources | 8, 9, 15 | 795 | 5.955e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 795. |
# | source_density | 814, 829 | 13 | 1 | sources | 9, 5 | 829 | 5.428e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 829. |
# | source_density | 812, 830 | 13 | 1 | sources | 9, 5 | 830 | 5.419e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 830. |
# | source_density | 811, 832 | 13 | 1 | sources | 9, 5 | 832 | 5.382e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 832. |
# | source_density | 810, 834 | 13 | 1 | sources | 9, 5 | 834 | 5.294e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 834. |
# | source_density | 839, 840 | 13 | 0 | sources | 5, 8 | 840 | 5.626e-04 | All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 840. |
# | source_density | 843, 844, 868, 869 | 89 | 2 | sources | 5, 9, 7, 8 | 844 | 5.821e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 844. |
# | source_density | 846, 847, 858 | 21 | 0 | sources | 8, 9, 7 | 846 | 4.975e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 846. |
# | source_density | 861, 862, 866, 867 | 34 | 2 | sources | 5, 9, 7, 8 | 862 | 5.257e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 862. |
# | source_density | 888, 889, 890 | 610 | 2 | sources | 5, 9, 11 | 889 | 4.802e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 889. |
# | source_density | 897, 898, 899 | 610 | 1 | sources | 5, 9, 8 | 897 | 4.677e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 897. |
# | source_density | 907, 908 | 1597 | 1 | sources | 5, 9 | 908 | 5.127e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 908. |
# | source_density | 910, 911 | 2584 | 0 | sources | 8, 9 | 911 | 5.469e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 911. |
# | source_density | 919, 920 | 6765 | 0 | sources | 8, 9 | 920 | 5.485e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 920. |
# | source_density | 921, 922 | 6765 | 2 | sources | 5, 9 | 922 | 5.067e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 922. |
# | source_density | 925, 926 | 10946 | 0 | sources | 8, 9 | 926 | 5.207e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 926. |
# | source_density | 927, 928 | 10946 | 2 | sources | 5, 9 | 928 | 5.593e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 928. |
# | source_density | 931, 932 | 17711 | 0 | sources | 8, 9 | 932 | 5.525e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 932. |
# | source_density | 945, 946 | 75025 | 2 | sources | 5, 9 | 946 | 5.008e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 946. |
# | source_density | 949, 950, 951 | 121393 | 0 | sources | 8, 9, 11 | 950 | 4.912e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 950. |
# | source_density | 955, 956 | 196418 | 1 | sources | 5, 9 | 956 | 5.896e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 956. |
# | source_density | 959, 960 | 317811 | 2 | sources | 5, 9 | 960 | 5.096e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 960. |
# | source_density | 964, 965 | 514229 | 2 | sources | 5, 9 | 965 | 5.347e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 965. |
# | source_density | 970, 971 | 832040 | 1 | sources | 5, 9 | 971 | 5.167e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 971. |
# | source_density | 973, 974, 975 | 1346269 | 0 | sources | 8, 9, 11 | 975 | 5.043e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 975. |
# | source_density | 976, 977, 1002 | 1346269 | 2 | sources | 5, 9, 7 | 977 | 5.641e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 977. |
# | source_density | 982, 983, 984 | 2178309 | 1 | sources | 5, 9, 11 | 982 | 4.821e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 982. |
# | source_density | 995, 998, 999 | 832040 | 1 | sources | 5, 7, 9 | 999 | 5.297e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 999. |
# | source_density | 1012, 1013, 1014, 1017 | 5702887 | 2 | sources | 5, 7, 9, 11 | 1014 | 4.834e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1014. |
# | source_density | 1023, 1025, 1026 | 14930352 | 0 | sources | 8, 9, 11 | 1023 | 4.932e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1023. |
# | source_density | 1027, 1028 | 14930352 | 2 | sources | 5, 7 | 1028 | 5.148e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1028. |
# | source_density | 1042, 1043, 1044 | 102334155 | 2 | sources | 5, 7, 9 | 1044 | 5.820e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1044. |
# | source_density | 1050, 1052 | 267914296 | 0 | sources | 8, 9 | 1052 | 5.319e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1052. |
# | source_density | 1053, 1054, 1055 | 267914296 | 2 | sources | 5, 7, 9 | 1055 | 5.183e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1055. |
# | source_density | 1057, 1058 | 267914296 | 1 | sources | 5, 9 | 1058 | 5.080e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1058. |
# | source_density | 1079, 1081 | 7778742049 | 0 | sources | 8, 9 | 1081 | 5.584e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1081. |
# | source_density | 1082, 1083, 1084 | 7778742049 | 2 | sources | 5, 7, 9 | 1084 | 5.516e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1084. |
# | source_density | 1090, 1091, 1092, 1093 | 20365011074 | 2 | sources | 5, 7, 9, 11 | 1092 | 4.981e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1092. |
# | source_density | 1096, 1097, 1098 | 32951280099 | 2 | sources | 5, 7, 9 | 1098 | 5.051e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1098. |
# | source_density | 1101, 1102, 1103, 1104 | 53316291173 | 2 | sources | 5, 7, 9, 11 | 1103 | 4.823e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1103. |
# | source_density | 1107, 1108, 1109, 1110 | 86267571272 | 2 | sources | 5, 7, 9, 11 | 1109 | 4.758e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1109. |
# | source_density | 1114, 1115 | 139583862445 | 1 | sources | 5, 9 | 1115 | 5.084e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1115. |
# | source_density | 1133, 1134 | 1548008755920 | 2 | sources | 5, 7 | 1134 | 5.016e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1134. |
# | source_density | 1136, 1140 | 2504730781961 | 0 | sources | 8, 9 | 1140 | 5.296e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1140. |
# | source_density | 1150, 1151, 1152, 1153 | 10610209877723 | 2 | sources | 5, 7, 9, 11 | 1152 | 4.831e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1152. |
# | source_density | 1156, 1157, 1158 | 17167680207565 | 2 | sources | 5, 7, 9 | 1158 | 5.574e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1158. |
# | source_density | 1159, 1160 | 17167680207565 | 1 | sources | 5, 9 | 1160 | 5.549e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1160. |
# | source_density | 1162, 1163, 1164 | 27777890085288 | 2 | sources | 5, 7, 9 | 1164 | 5.354e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1164. |
# | source_density | 1172, 1173 | 72723460378141 | 1 | sources | 5, 9 | 1173 | 5.446e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1173. |
# | source_density | 1175, 1176 | 117669030670994 | 2 | sources | 5, 7 | 1176 | 5.037e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1176. |
# | source_density | 1184, 1185, 1186 | 308061521720129 | 2 | sources | 5, 7, 9 | 1184 | 4.909e-04 | All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1184. |
# | source_density | 1190, 1191, 1192 | 498454012769264 | 2 | sources | 5, 7, 9 | 1192 | 5.422e-04 | At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1192. |
# | ... | 43 more rows omitted here; see CSV. |

# %% [markdown]
# ## Appendix: All Detected Series Plots

# %% [markdown]
# ### ringdown: runs 744, 751
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 751.
#
# ![Ringdown-parameter series: seed89 target0, runs 744-751, ringdown_value=0.25, 0.35](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target0_runs744_751.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 744, 751. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 751.*

# %% [markdown]
# ### ringdown: runs 745, 750
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 750.
#
# ![Ringdown-parameter series: seed89 target2, runs 745-750, ringdown_value=0.25, 0.35](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target2_runs745_750.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 745, 750. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 750.*

# %% [markdown]
# ### ringdown: runs 746, 749
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 749.
#
# ![Ringdown-parameter series: seed89 target1, runs 746-749, ringdown_value=0.25, 0.35](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target1_runs746_749.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 746, 749. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 749.*

# %% [markdown]
# ### ringdown: runs 754, 835
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 835.
#
# ![Ringdown-parameter series: seed89 target1, runs 754-835, ringdown_value=0.25, 0.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target1_runs754_835.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 754, 835. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 835.*

# %% [markdown]
# ### ringdown: runs 755, 759, 843
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 843.
#
# ![Ringdown-parameter series: seed89 target2, runs 755-843, ringdown_value=0.25, 0.25, 0.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target2_runs755_843.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 755, 759, 843. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 843.*

# %% [markdown]
# ### ringdown: runs 765, 779
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 779.
#
# ![Ringdown-parameter series: seed89 target2, runs 765-779, ringdown_value=0.25, 0.35](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target2_runs765_779.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 765, 779. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 779.*

# %% [markdown]
# ### ringdown: runs 780, 782
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 780.
#
# ![Ringdown-parameter series: seed89 target2, runs 780-782, ringdown_value=0.25, 0.35](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target2_runs780_782.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 780, 782. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 780.*

# %% [markdown]
# ### ringdown: runs 783, 868
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 783.
#
# ![Ringdown-parameter series: seed89 target2, runs 783-868, ringdown_value=0.25, 0.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target2_runs783_868.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 783, 868. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 783.*

# %% [markdown]
# ### ringdown: runs 786, 792, 793, 794, 819
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 794.
#
# ![Ringdown-parameter series: seed89 target1, runs 786-819, ringdown_value=0.25, 0.25, 0.25, 0.35, 0.459375](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target1_runs786_819.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 786, 792, 793, 794, 819. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 794.*

# %% [markdown]
# ### ringdown: runs 787, 796, 822, 844
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 796.
#
# ![Ringdown-parameter series: seed89 target2, runs 787-844, ringdown_value=0.25, 0.35, 0.459375, 0.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target2_runs787_844.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 787, 796, 822, 844. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 796.*

# %% [markdown]
# ### ringdown: runs 788, 797
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 797.
#
# ![Ringdown-parameter series: seed89 target0, runs 788-797, ringdown_value=0.25, 0.35](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target0_runs788_797.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 788, 797. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 797.*

# %% [markdown]
# ### ringdown: runs 789, 795, 823, 842
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 795.
#
# ![Ringdown-parameter series: seed89 target0, runs 789-842, ringdown_value=0.25, 0.35, 0.459375, 0.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target0_runs789_842.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 789, 795, 823, 842. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 795.*

# %% [markdown]
# ### ringdown: runs 790, 798
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 790.
#
# ![Ringdown-parameter series: seed89 target1, runs 790-798, ringdown_value=0.25, 0.35](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target1_runs790_798.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 790, 798. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 790.*

# %% [markdown]
# ### ringdown: runs 791, 869
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 791.
#
# ![Ringdown-parameter series: seed89 target2, runs 791-869, ringdown_value=0.25, 0.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed89_target2_runs791_869.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 791, 869. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 791.*

# %% [markdown]
# ### ringdown: runs 802, 826, 846, 848, 849, 852, 853, 854, 855, 856
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 802.
#
# ![Ringdown-parameter series: seed21 target0, runs 802-856, ringdown_value=0.35, 0.459375, 0.5, 0.475, 0.49375, 0.496875, 0.4953125, 0.49453125, 0.494921875, 0.4947265625](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed21_target0_runs802_856.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 802, 826, 846, 848, 849, 852, 853, 854, 855, 856. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 802.*

# %% [markdown]
# ### ringdown: runs 803, 820
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 803.
#
# ![Ringdown-parameter series: seed21 target1, runs 803-820, ringdown_value=0.35, 0.459375](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed21_target1_runs803_820.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 803, 820. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 803.*

# %% [markdown]
# ### ringdown: runs 804, 825, 850, 864
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 804.
#
# ![Ringdown-parameter series: seed21 target2, runs 804-864, ringdown_value=0.35, 0.459375, 0.49375, 0.49453125](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed21_target2_runs804_864.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 804, 825, 850, 864. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 804.*

# %% [markdown]
# ### ringdown: runs 805, 817, 840
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 805.
#
# ![Ringdown-parameter series: seed13 target0, runs 805-840, ringdown_value=0.35, 0.459375, 0.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed13_target0_runs805_840.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 805, 817, 840. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 805.*

# %% [markdown]
# ### ringdown: runs 806, 809, 810, 811, 812, 813, 814
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 806.
#
# ![Ringdown-parameter series: seed13 target1, runs 806-814, ringdown_value=0.35, 0.45, 0.5, 0.475, 0.4625, 0.45625, 0.459375](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed13_target1_runs806_814.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 806, 809, 810, 811, 812, 813, 814. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 806.*

# %% [markdown]
# ### ringdown: runs 807, 816
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 807.
#
# ![Ringdown-parameter series: seed13 target2, runs 807-816, ringdown_value=0.35, 0.459375](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed13_target2_runs807_816.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 807, 816. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 807.*

# %% [markdown]
# ### ringdown: runs 829, 830, 831, 832, 834
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 829.
#
# ![Ringdown-parameter series: seed13 target1, runs 829-834, ringdown_value=0.459375, 0.4625, 0.46875, 0.475, 0.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed13_target1_runs829_834.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 829, 830, 831, 832, 834. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 829.*

# %% [markdown]
# ### ringdown: runs 889, 891, 892, 893, 894, 895, 896
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 894.
#
# ![Ringdown-parameter series: seed610 target2, runs 889-896, ringdown_value=0.5, 0.49453125, 0.475, 0.459375, 0.4, 0.35, 0.25](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/ringdown_seed610_target2_runs889_896.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 889, 891, 892, 893, 894, 895, 896. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 894.*

# %% [markdown]
# ### source_density: runs 754, 785, 786, 790, 792, 793
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 754.
#
# ![Source-density series: seed89 target1, runs 754-793, sources=5, 7, 9, 8, 9, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed89_target1_runs754_793.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 754, 785, 786, 790, 792, 793. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 754.*

# %% [markdown]
# ### source_density: runs 755, 759, 783, 787, 791
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 787.
#
# ![Source-density series: seed89 target2, runs 755-791, sources=5, 5, 7, 9, 8](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed89_target2_runs755_791.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 755, 759, 783, 787, 791. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 787.*

# %% [markdown]
# ### source_density: runs 756, 784, 788, 789
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 789.
#
# ![Source-density series: seed89 target0, runs 756-789, sources=5, 7, 9, 8](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed89_target0_runs756_789.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 756, 784, 788, 789. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 789.*

# %% [markdown]
# ### source_density: runs 765, 780, 781
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 780.
#
# ![Source-density series: seed89 target2, runs 765-781, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed89_target2_runs765_781.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 765, 780, 781. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 780.*

# %% [markdown]
# ### source_density: runs 779, 782
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 782.
#
# ![Source-density series: seed89 target2, runs 779-782, sources=5, 7](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed89_target2_runs779_782.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 779, 782. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 782.*

# %% [markdown]
# ### source_density: runs 794, 798
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 794.
#
# ![Source-density series: seed89 target1, runs 794-798, sources=9, 8](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed89_target1_runs794_798.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 794, 798. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 794.*

# %% [markdown]
# ### source_density: runs 795, 797, 801
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 795.
#
# ![Source-density series: seed89 target0, runs 795-801, sources=8, 9, 15](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed89_target0_runs795_801.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 795, 797, 801. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 795.*

# %% [markdown]
# ### source_density: runs 810, 834
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 834.
#
# ![Source-density series: seed13 target1, runs 810-834, sources=9, 5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed13_target1_runs810_834.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 810, 834. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 834.*

# %% [markdown]
# ### source_density: runs 811, 832
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 832.
#
# ![Source-density series: seed13 target1, runs 811-832, sources=9, 5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed13_target1_runs811_832.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 811, 832. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 832.*

# %% [markdown]
# ### source_density: runs 812, 830
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 830.
#
# ![Source-density series: seed13 target1, runs 812-830, sources=9, 5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed13_target1_runs812_830.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 812, 830. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 830.*

# %% [markdown]
# ### source_density: runs 814, 829
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 829.
#
# ![Source-density series: seed13 target1, runs 814-829, sources=9, 5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed13_target1_runs814_829.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 814, 829. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 829.*

# %% [markdown]
# ### source_density: runs 839, 840
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 840.
#
# ![Source-density series: seed13 target0, runs 839-840, sources=5, 8](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed13_target0_runs839_840.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 839, 840. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 840.*

# %% [markdown]
# ### source_density: runs 843, 844, 868, 869
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 844.
#
# ![Source-density series: seed89 target2, runs 843-869, sources=5, 9, 7, 8](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed89_target2_runs843_869.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 843, 844, 868, 869. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 844.*

# %% [markdown]
# ### source_density: runs 846, 847, 858
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 846.
#
# ![Source-density series: seed21 target0, runs 846-858, sources=8, 9, 7](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed21_target0_runs846_858.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 846, 847, 858. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 846.*

# %% [markdown]
# ### source_density: runs 861, 862, 866, 867
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 862.
#
# ![Source-density series: seed34 target2, runs 861-867, sources=5, 9, 7, 8](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed34_target2_runs861_867.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 861, 862, 866, 867. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 862.*

# %% [markdown]
# ### source_density: runs 888, 889, 890
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 889.
#
# ![Source-density series: seed610 target2, runs 888-890, sources=5, 9, 11](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed610_target2_runs888_890.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 888, 889, 890. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 889.*

# %% [markdown]
# ### source_density: runs 897, 898, 899
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 897.
#
# ![Source-density series: seed610 target1, runs 897-899, sources=5, 9, 8](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed610_target1_runs897_899.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 897, 898, 899. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 897.*

# %% [markdown]
# ### source_density: runs 907, 908
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 908.
#
# ![Source-density series: seed1597 target1, runs 907-908, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed1597_target1_runs907_908.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 907, 908. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 908.*

# %% [markdown]
# ### source_density: runs 910, 911
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 911.
#
# ![Source-density series: seed2584 target0, runs 910-911, sources=8, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed2584_target0_runs910_911.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 910, 911. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 911.*

# %% [markdown]
# ### source_density: runs 919, 920
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 920.
#
# ![Source-density series: seed6765 target0, runs 919-920, sources=8, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed6765_target0_runs919_920.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 919, 920. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 920.*

# %% [markdown]
# ### source_density: runs 921, 922
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 922.
#
# ![Source-density series: seed6765 target2, runs 921-922, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed6765_target2_runs921_922.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 921, 922. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 922.*

# %% [markdown]
# ### source_density: runs 925, 926
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 926.
#
# ![Source-density series: seed10946 target0, runs 925-926, sources=8, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed10946_target0_runs925_926.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 925, 926. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 926.*

# %% [markdown]
# ### source_density: runs 927, 928
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 928.
#
# ![Source-density series: seed10946 target2, runs 927-928, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed10946_target2_runs927_928.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 927, 928. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 928.*

# %% [markdown]
# ### source_density: runs 931, 932
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 932.
#
# ![Source-density series: seed17711 target0, runs 931-932, sources=8, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed17711_target0_runs931_932.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 931, 932. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 932.*

# %% [markdown]
# ### source_density: runs 945, 946
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 946.
#
# ![Source-density series: seed75025 target2, runs 945-946, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed75025_target2_runs945_946.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 945, 946. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 946.*

# %% [markdown]
# ### source_density: runs 949, 950, 951
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 950.
#
# ![Source-density series: seed121393 target0, runs 949-951, sources=8, 9, 11](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed121393_target0_runs949_951.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 949, 950, 951. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 950.*

# %% [markdown]
# ### source_density: runs 955, 956
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 956.
#
# ![Source-density series: seed196418 target1, runs 955-956, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed196418_target1_runs955_956.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 955, 956. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 956.*

# %% [markdown]
# ### source_density: runs 959, 960
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 960.
#
# ![Source-density series: seed317811 target2, runs 959-960, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed317811_target2_runs959_960.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 959, 960. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 960.*

# %% [markdown]
# ### source_density: runs 964, 965
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 965.
#
# ![Source-density series: seed514229 target2, runs 964-965, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed514229_target2_runs964_965.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 964, 965. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 965.*

# %% [markdown]
# ### source_density: runs 970, 971
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 971.
#
# ![Source-density series: seed832040 target1, runs 970-971, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed832040_target1_runs970_971.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 970, 971. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 971.*

# %% [markdown]
# ### source_density: runs 973, 974, 975
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 975.
#
# ![Source-density series: seed1346269 target0, runs 973-975, sources=8, 9, 11](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed1346269_target0_runs973_975.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 973, 974, 975. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 975.*

# %% [markdown]
# ### source_density: runs 976, 977, 1002
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 977.
#
# ![Source-density series: seed1346269 target2, runs 976-1002, sources=5, 9, 7](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed1346269_target2_runs976_1002.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 976, 977, 1002. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 977.*

# %% [markdown]
# ### source_density: runs 982, 983, 984
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 982.
#
# ![Source-density series: seed2178309 target1, runs 982-984, sources=5, 9, 11](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed2178309_target1_runs982_984.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 982, 983, 984. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 982.*

# %% [markdown]
# ### source_density: runs 995, 998, 999
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 999.
#
# ![Source-density series: seed832040 target1, runs 995-999, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed832040_target1_runs995_999.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 995, 998, 999. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 999.*

# %% [markdown]
# ### source_density: runs 1012, 1013, 1014, 1017
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1014.
#
# ![Source-density series: seed5702887 target2, runs 1012-1017, sources=5, 7, 9, 11](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed5702887_target2_runs1012_1017.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1012, 1013, 1014, 1017. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1014.*

# %% [markdown]
# ### source_density: runs 1023, 1025, 1026
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1023.
#
# ![Source-density series: seed14930352 target0, runs 1023-1026, sources=8, 9, 11](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed14930352_target0_runs1023_1026.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1023, 1025, 1026. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1023.*

# %% [markdown]
# ### source_density: runs 1027, 1028
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1028.
#
# ![Source-density series: seed14930352 target2, runs 1027-1028, sources=5, 7](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed14930352_target2_runs1027_1028.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1027, 1028. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1028.*

# %% [markdown]
# ### source_density: runs 1042, 1043, 1044
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1044.
#
# ![Source-density series: seed102334155 target2, runs 1042-1044, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed102334155_target2_runs1042_1044.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1042, 1043, 1044. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1044.*

# %% [markdown]
# ### source_density: runs 1050, 1052
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1052.
#
# ![Source-density series: seed267914296 target0, runs 1050-1052, sources=8, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed267914296_target0_runs1050_1052.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1050, 1052. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1052.*

# %% [markdown]
# ### source_density: runs 1053, 1054, 1055
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1055.
#
# ![Source-density series: seed267914296 target2, runs 1053-1055, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed267914296_target2_runs1053_1055.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1053, 1054, 1055. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1055.*

# %% [markdown]
# ### source_density: runs 1057, 1058
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1058.
#
# ![Source-density series: seed267914296 target1, runs 1057-1058, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed267914296_target1_runs1057_1058.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1057, 1058. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1058.*

# %% [markdown]
# ### source_density: runs 1079, 1081
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1081.
#
# ![Source-density series: seed7778742049 target0, runs 1079-1081, sources=8, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed7778742049_target0_runs1079_1081.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1079, 1081. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1081.*

# %% [markdown]
# ### source_density: runs 1082, 1083, 1084
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1084.
#
# ![Source-density series: seed7778742049 target2, runs 1082-1084, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed7778742049_target2_runs1082_1084.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1082, 1083, 1084. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1084.*

# %% [markdown]
# ### source_density: runs 1090, 1091, 1092, 1093
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1092.
#
# ![Source-density series: seed20365011074 target2, runs 1090-1093, sources=5, 7, 9, 11](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed20365011074_target2_runs1090_1093.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1090, 1091, 1092, 1093. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1092.*

# %% [markdown]
# ### source_density: runs 1096, 1097, 1098
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1098.
#
# ![Source-density series: seed32951280099 target2, runs 1096-1098, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed32951280099_target2_runs1096_1098.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1096, 1097, 1098. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1098.*

# %% [markdown]
# ### source_density: runs 1101, 1102, 1103, 1104
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1103.
#
# ![Source-density series: seed53316291173 target2, runs 1101-1104, sources=5, 7, 9, 11](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed53316291173_target2_runs1101_1104.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1101, 1102, 1103, 1104. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1103.*

# %% [markdown]
# ### source_density: runs 1107, 1108, 1109, 1110
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1109.
#
# ![Source-density series: seed86267571272 target2, runs 1107-1110, sources=5, 7, 9, 11](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed86267571272_target2_runs1107_1110.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1107, 1108, 1109, 1110. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1109.*

# %% [markdown]
# ### source_density: runs 1114, 1115
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1115.
#
# ![Source-density series: seed139583862445 target1, runs 1114-1115, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed139583862445_target1_runs1114_1115.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1114, 1115. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1115.*

# %% [markdown]
# ### source_density: runs 1133, 1134
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1134.
#
# ![Source-density series: seed1548008755920 target2, runs 1133-1134, sources=5, 7](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed1548008755920_target2_runs1133_1134.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1133, 1134. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1134.*

# %% [markdown]
# ### source_density: runs 1136, 1140
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1140.
#
# ![Source-density series: seed2504730781961 target0, runs 1136-1140, sources=8, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed2504730781961_target0_runs1136_1140.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1136, 1140. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1140.*

# %% [markdown]
# ### source_density: runs 1150, 1151, 1152, 1153
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1152.
#
# ![Source-density series: seed10610209877723 target2, runs 1150-1153, sources=5, 7, 9, 11](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed10610209877723_target2_runs1150_1153.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1150, 1151, 1152, 1153. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1152.*

# %% [markdown]
# ### source_density: runs 1156, 1157, 1158
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1158.
#
# ![Source-density series: seed17167680207565 target2, runs 1156-1158, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed17167680207565_target2_runs1156_1158.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1156, 1157, 1158. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1158.*

# %% [markdown]
# ### source_density: runs 1159, 1160
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1160.
#
# ![Source-density series: seed17167680207565 target1, runs 1159-1160, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed17167680207565_target1_runs1159_1160.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1159, 1160. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1160.*

# %% [markdown]
# ### source_density: runs 1162, 1163, 1164
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1164.
#
# ![Source-density series: seed27777890085288 target2, runs 1162-1164, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed27777890085288_target2_runs1162_1164.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1162, 1163, 1164. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1164.*

# %% [markdown]
# ### source_density: runs 1172, 1173
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1173.
#
# ![Source-density series: seed72723460378141 target1, runs 1172-1173, sources=5, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed72723460378141_target1_runs1172_1173.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1172, 1173. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1173.*

# %% [markdown]
# ### source_density: runs 1175, 1176
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1176.
#
# ![Source-density series: seed117669030670994 target2, runs 1175-1176, sources=5, 7](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed117669030670994_target2_runs1175_1176.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1175, 1176. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1176.*

# %% [markdown]
# ### source_density: runs 1184, 1185, 1186
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1184.
#
# ![Source-density series: seed308061521720129 target2, runs 1184-1186, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed308061521720129_target2_runs1184_1186.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1184, 1185, 1186. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1184.*

# %% [markdown]
# ### source_density: runs 1190, 1191, 1192
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1192.
#
# ![Source-density series: seed498454012769264 target2, runs 1190-1192, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed498454012769264_target2_runs1190_1192.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1190, 1191, 1192. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1192.*

# %% [markdown]
# ### source_density: runs 1195, 1196, 1197
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1197.
#
# ![Source-density series: seed806515534489393 target2, runs 1195-1197, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed806515534489393_target2_runs1195_1197.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1195, 1196, 1197. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1197.*

# %% [markdown]
# ### source_density: runs 1203, 1204
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1204.
#
# ![Source-density series: seed2111485081748050 target2, runs 1203-1204, sources=5, 7](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed2111485081748050_target2_runs1203_1204.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1203, 1204. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1204.*

# %% [markdown]
# ### source_density: runs 1207, 1208, 1209
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1209.
#
# ![Source-density series: seed3416454629006707 target2, runs 1207-1209, sources=5, 7, 9](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed3416454629006707_target2_runs1207_1209.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1207, 1208, 1209. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1209.*

# %% [markdown]
# ### source_density: runs 1216, 1217, 1218
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1217.
#
# ![Source-density series: seed5527939710754757 target1, runs 1216-1218, sources=5, 9, 11](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/source_density_seed5527939710754757_target1_runs1216_1218.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1216, 1217, 1218. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1217.*

# %% [markdown]
# ### tx_rx_offset: runs 744, 756
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 744.
#
# ![Tx/Rx-offset series: seed89 target0, runs 744-756, tx_rx_offset_mm=50.0, 60.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed89_target0_runs744_756.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 744, 756. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 744.*

# %% [markdown]
# ### tx_rx_offset: runs 745, 755, 759, 760, 761, 762, 763
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 745.
#
# ![Tx/Rx-offset series: seed89 target2, runs 745-763, tx_rx_offset_mm=50.0, 60.0, 60.0, 55.0, 52.5, 51.25, 50.625](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed89_target2_runs745_763.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 745, 755, 759, 760, 761, 762, 763. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 745.*

# %% [markdown]
# ### tx_rx_offset: runs 746, 754
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 746.
#
# ![Tx/Rx-offset series: seed89 target1, runs 746-754, tx_rx_offset_mm=50.0, 60.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed89_target1_runs746_754.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 746, 754. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 746.*

# %% [markdown]
# ### tx_rx_offset: runs 765, 766, 767, 769
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 769.
#
# ![Tx/Rx-offset series: seed89 target2, runs 765-769, tx_rx_offset_mm=50.3125, 50.15625, 50.078125, 50.0390625](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed89_target2_runs765_769.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 765, 766, 767, 769. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 769.*

# %% [markdown]
# ### tx_rx_offset: runs 771, 772
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 772.
#
# ![Tx/Rx-offset series: seed21 target2, runs 771-772, tx_rx_offset_mm=50.0390625, 50.3125](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed21_target2_runs771_772.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 771, 772. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 772.*

# %% [markdown]
# ### tx_rx_offset: runs 799, 800
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 799.
#
# ![Tx/Rx-offset series: seed89 target0, runs 799-800, tx_rx_offset_mm=60.0, 60.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed89_target0_runs799_800.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 799, 800. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 799.*

# %% [markdown]
# ### tx_rx_offset: runs 897, 1224, 1234, 1235, 1236
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1235.
#
# ![Tx/Rx-offset series: seed610 target1, runs 897-1236, tx_rx_offset_mm=60.0, 52.5, 50.0, 55.0, 57.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed610_target1_runs897_1236.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 897, 1224, 1234, 1235, 1236. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1235.*

# %% [markdown]
# ### tx_rx_offset: runs 970, 995, 996, 997
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 995.
#
# ![Tx/Rx-offset series: seed832040 target1, runs 970-997, tx_rx_offset_mm=60.0, 52.5, 50.0, 55.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed832040_target1_runs970_997.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 970, 995, 996, 997. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 995.*

# %% [markdown]
# ### tx_rx_offset: runs 971, 999
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 999.
#
# ![Tx/Rx-offset series: seed832040 target1, runs 971-999, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed832040_target1_runs971_999.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 971, 999. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 999.*

# %% [markdown]
# ### tx_rx_offset: runs 973, 1000
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1000.
#
# ![Tx/Rx-offset series: seed1346269 target0, runs 973-1000, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed1346269_target0_runs973_1000.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 973, 1000. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1000.*

# %% [markdown]
# ### tx_rx_offset: runs 976, 1001
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 976.
#
# ![Tx/Rx-offset series: seed1346269 target2, runs 976-1001, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed1346269_target2_runs976_1001.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 976, 1001. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 976.*

# %% [markdown]
# ### tx_rx_offset: runs 978, 1003
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1003.
#
# ![Tx/Rx-offset series: seed1346269 target1, runs 978-1003, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed1346269_target1_runs978_1003.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 978, 1003. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1003.*

# %% [markdown]
# ### tx_rx_offset: runs 980, 992
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 980.
#
# ![Tx/Rx-offset series: seed2178309 target0, runs 980-992, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed2178309_target0_runs980_992.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 980, 992. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 980.*

# %% [markdown]
# ### tx_rx_offset: runs 981, 993
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 993.
#
# ![Tx/Rx-offset series: seed2178309 target2, runs 981-993, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed2178309_target2_runs981_993.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 981, 993. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 993.*

# %% [markdown]
# ### tx_rx_offset: runs 982, 987, 988, 989, 990, 991
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 991.
#
# ![Tx/Rx-offset series: seed2178309 target1, runs 982-991, tx_rx_offset_mm=60.0, 50.0, 45.0, 55.0, 57.5, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed2178309_target1_runs982_991.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 982, 987, 988, 989, 990, 991. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 991.*

# %% [markdown]
# ### tx_rx_offset: runs 1008, 1009, 1010, 1011
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1011.
#
# ![Tx/Rx-offset series: seed5702887 target0, runs 1008-1011, tx_rx_offset_mm=60.0, 52.5, 50.0, 45.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed5702887_target0_runs1008_1011.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1008, 1009, 1010, 1011. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1011.*

# %% [markdown]
# ### tx_rx_offset: runs 1014, 1015, 1016
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1014.
#
# ![Tx/Rx-offset series: seed5702887 target2, runs 1014-1016, tx_rx_offset_mm=60.0, 45.0, 65.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed5702887_target2_runs1014_1016.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1014, 1015, 1016. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1014.*

# %% [markdown]
# ### tx_rx_offset: runs 1021, 1022
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1022.
#
# ![Tx/Rx-offset series: seed9227465 target1, runs 1021-1022, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed9227465_target1_runs1021_1022.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1021, 1022. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1022.*

# %% [markdown]
# ### tx_rx_offset: runs 1023, 1024
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1023.
#
# ![Tx/Rx-offset series: seed14930352 target0, runs 1023-1024, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed14930352_target0_runs1023_1024.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1023, 1024. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1023.*

# %% [markdown]
# ### tx_rx_offset: runs 1032, 1033
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1033.
#
# ![Tx/Rx-offset series: seed24157817 target1, runs 1032-1033, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed24157817_target1_runs1032_1033.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1032, 1033. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1033.*

# %% [markdown]
# ### tx_rx_offset: runs 1039, 1040
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1040.
#
# ![Tx/Rx-offset series: seed63245986 target1, runs 1039-1040, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed63245986_target1_runs1039_1040.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1039, 1040. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1040.*

# %% [markdown]
# ### tx_rx_offset: runs 1045, 1046
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1046.
#
# ![Tx/Rx-offset series: seed102334155 target1, runs 1045-1046, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed102334155_target1_runs1045_1046.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1045, 1046. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1046.*

# %% [markdown]
# ### tx_rx_offset: runs 1050, 1051
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1050.
#
# ![Tx/Rx-offset series: seed267914296 target0, runs 1050-1051, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed267914296_target0_runs1050_1051.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1050, 1051. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1050.*

# %% [markdown]
# ### tx_rx_offset: runs 1056, 1057
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1057.
#
# ![Tx/Rx-offset series: seed267914296 target1, runs 1056-1057, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed267914296_target1_runs1056_1057.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1056, 1057. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1057.*

# %% [markdown]
# ### tx_rx_offset: runs 1061, 1062
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1062.
#
# ![Tx/Rx-offset series: seed433494437 target1, runs 1061-1062, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed433494437_target1_runs1061_1062.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1061, 1062. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1062.*

# %% [markdown]
# ### tx_rx_offset: runs 1063, 1064
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1064.
#
# ![Tx/Rx-offset series: seed701408733 target0, runs 1063-1064, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed701408733_target0_runs1063_1064.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1063, 1064. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1064.*

# %% [markdown]
# ### tx_rx_offset: runs 1079, 1080
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1079.
#
# ![Tx/Rx-offset series: seed7778742049 target0, runs 1079-1080, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed7778742049_target0_runs1079_1080.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1079, 1080. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1079.*

# %% [markdown]
# ### tx_rx_offset: runs 1090, 1225
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1225.
#
# ![Tx/Rx-offset series: seed20365011074 target2, runs 1090-1225, tx_rx_offset_mm=60.0, 50.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed20365011074_target2_runs1090_1225.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1090, 1225. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1225.*

# %% [markdown]
# ### tx_rx_offset: runs 1120, 1121, 1122, 1123
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1123.
#
# ![Tx/Rx-offset series: seed365435296162 target0, runs 1120-1123, tx_rx_offset_mm=60.0, 52.5, 50.0, 45.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed365435296162_target0_runs1120_1123.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1120, 1121, 1122, 1123. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1123.*

# %% [markdown]
# ### tx_rx_offset: runs 1136, 1137, 1138, 1139
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1139.
#
# ![Tx/Rx-offset series: seed2504730781961 target0, runs 1136-1139, tx_rx_offset_mm=60.0, 52.5, 50.0, 45.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed2504730781961_target0_runs1136_1139.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1136, 1137, 1138, 1139. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1139.*

# %% [markdown]
# ### tx_rx_offset: runs 1166, 1167
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1167.
#
# ![Tx/Rx-offset series: seed44945570292853 target0, runs 1166-1167, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed44945570292853_target0_runs1166_1167.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1166, 1167. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1167.*

# %% [markdown]
# ### tx_rx_offset: runs 1178, 1179
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1179.
#
# ![Tx/Rx-offset series: seed190392491049135 target0, runs 1178-1179, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed190392491049135_target0_runs1178_1179.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1178, 1179. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1179.*

# %% [markdown]
# ### tx_rx_offset: runs 1182, 1183
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1183.
#
# ![Tx/Rx-offset series: seed308061521720129 target0, runs 1182-1183, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed308061521720129_target0_runs1182_1183.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1182, 1183. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1183.*

# %% [markdown]
# ### tx_rx_offset: runs 1184, 1226
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1184.
#
# ![Tx/Rx-offset series: seed308061521720129 target2, runs 1184-1226, tx_rx_offset_mm=60.0, 50.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed308061521720129_target2_runs1184_1226.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1184, 1226. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1184.*

# %% [markdown]
# ### tx_rx_offset: runs 1188, 1189
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1189.
#
# ![Tx/Rx-offset series: seed498454012769264 target0, runs 1188-1189, tx_rx_offset_mm=60.0, 52.5](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed498454012769264_target0_runs1188_1189.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1188, 1189. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1189.*

# %% [markdown]
# ### tx_rx_offset: runs 1211, 1212, 1213, 1214
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1214.
#
# ![Tx/Rx-offset series: seed5527939710754757 target0, runs 1211-1214, tx_rx_offset_mm=60.0, 52.5, 50.0, 45.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed5527939710754757_target0_runs1211_1214.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1211, 1212, 1213, 1214. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1214.*

# %% [markdown]
# ### tx_rx_offset: runs 1216, 1223, 1240
#
# All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1240.
#
# ![Tx/Rx-offset series: seed5527939710754757 target1, runs 1216-1240, tx_rx_offset_mm=60.0, 52.5, 55.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed5527939710754757_target1_runs1216_1240.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1216, 1223, 1240. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows stayed below the strict 5.0e-04 base-margin cutoff; best tested run is 1240.*

# %% [markdown]
# ### tx_rx_offset: runs 1219, 1245, 1251
#
# All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1245.
#
# ![Tx/Rx-offset series: seed13 target2, runs 1219-1251, tx_rx_offset_mm=25.0, 50.0, 50.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed13_target2_runs1219_1251.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1219, 1245, 1251. The dashed cutoff shows which tested settings reach moderate radius confidence. All tested rows cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1245.*

# %% [markdown]
# ### tx_rx_offset: runs 1221, 1246, 1252
#
# At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1246.
#
# ![Tx/Rx-offset series: seed21 target2, runs 1221-1252, tx_rx_offset_mm=25.0, 50.0, 50.0](../../../outputs/summary_tables/wk03_experiment_700_1259_holistic_evaluation/figures/series_charts/tx_rx_offset_seed21_target2_runs1221_1252.png)
#
# *Figure: This automatically generated series plot compares the varied setting against base margin for runs 1221, 1246, 1252. The dashed cutoff shows which tested settings reach moderate radius confidence. At least one row cleared the strict 5.0e-04 base-margin cutoff; best tested run is 1246.*

# %% [markdown]
# ## Recommended Next Increment
#
# The next report increment should add a target1-specific synthesis before any
# new GPU marathon:
#
# 1. Compare all target1 weak/rescue branches after output experiment 900.
# 2. Separate source-density rescue successes from unresolved cases.
# 3. Decide whether unresolved exact-geometry target1 rows should use Tx/Rx
#    acquisition probes, a revised confidence threshold, or a broader source/noise
#    model before more Fibonacci seed replication.
#
# This notebook deliberately stops at the seed5527939710754757 branch because
# that branch produced a negative 11-source escalation and needs interpretation,
# not more blind queueing.
