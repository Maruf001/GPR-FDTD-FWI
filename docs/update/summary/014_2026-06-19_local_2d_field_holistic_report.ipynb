# %% [markdown]
# # Local 2D And Field Holistic Report
#
# Generated: 2026-06-19.
#
# Scope:
#
# - Recent synthetic 2D outputs: `outputs/experiments/1200_...` through `outputs/experiments/1358_...`.
# - Field outputs: `outputs/field_experiments/local_gssi_51600s_2026_06_09` runs `001` through `156`.
# - Primary field checkpoint: `outputs/field_experiments/local_gssi_51600s_2026_06_09/156_gssi51600s_controlled_collection_critical_path`.
#
# This notebook is report-facing. It summarizes the recent synthetic 2D work and
# the full local GSSI field sequence without launching more experiments.

# %% [markdown]
# ## Executive Summary
#
# The synthetic 2D campaign did not close because the 3D work started elsewhere.
# It reached a local mechanism checkpoint: a fixed-radius target1 branch lock
# converted the target2 close14 repaired branch from a residual 1 mm state into
# exact geometry in one guarded unlock probe. This is usable as a narrow
# mechanism result, not as a general detector policy or detector-seeded FWI claim.
#
# The field campaign also reached a natural checkpoint, not an abrupt stop. Runs
# `137-156` close a complete field-side logic block: controlled acquisition
# design, existing-archive manifest, packet template, validation, metadata
# recovery, handoff, and gate-level critical path. The current archive is
# classified as independent 2D line profiles, not a 3D survey, and it cannot
# unblock any acceptance gate by itself.
#
# The next report should treat the two domains separately: synthetic 2D supports
# an acquisition-aware resolution/ambiguity study; the field archive supports
# QC, timing-risk analysis, and a controlled 2D collection protocol, but not
# field FWI or heavy GPU work from the current archive alone.

# %% [markdown]
# ## Scope Counts
#
# ![Report scope counts](../../../outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/local_2d_field_scope_counts.png)
#
# *Figure: Counts of recent synthetic outputs, field outputs, manifests, claim rows, figure rows, and field acceptance gates included in this report.*
#
# Key metrics:
#
# | Domain | Metric | Value | Interpretation |
# | --- | --- | --- | --- |
# | synthetic_2d | recent_window_first_run | 1200 | report window lower bound |
# | synthetic_2d | recent_window_last_run | 1358 | latest synthetic output in scope |
# | synthetic_2d | recent_output_dir_count | 159 | numbered output directories from run 1200 onward |
# | synthetic_2d | recent_manifest_count | 157 | recent output directories with run_manifest.json |
# | synthetic_2d | claim_table_rows | 32 | paper-facing claim rows in latest table pack |
# | synthetic_2d | synthetic_publication_figures | 9 | synthetic figures in latest table pack |
# | synthetic_2d | lock_selected_target_index | 1 | truth-free lock candidate selected before unlock probe |
# | synthetic_2d | lock_objective_penalty_rel | 0.034 | relative objective penalty for locking target1 to exact truth branch |
# | synthetic_2d | downstream_truth_clearance_before_mm | -0.962 | target2 clearance before target1 lock |
# | synthetic_2d | downstream_truth_clearance_after_mm | 0 | target2 clearance after target1 lock |
# | synthetic_2d | unlock_probe_final_linf_error_mm | 0 | final geometry error after guarded unlock probe |
# | synthetic_2d | locking_mechanism_claim_ready | True | single-branch mechanism evidence is usable |
# | synthetic_2d | general_detector_policy_ready | False | general detector policy claim status |
# | synthetic_2d | broad_gpu_queue_ready | False | whether current endpoint opens broad GPU queue |
# | field | field_first_run | 1 | first field output in local archive |
# | field | field_last_run | 156 | latest field output in scope |
# | field | field_run_count | 156 | numbered field output directories |
# | field | field_manifest_count | 156 | field output directories with run_manifest.json |
# | field | field_geometry_type | independent_2d_line_profiles | survey geometry classification |
# | field | is_3d_survey | False | whether the current field archive is a 3D survey |
# | field | field_gate_count | 7 | acceptance gates at critical path checkpoint |
# | field | field_ready_gate_count | 0 | gates ready at checkpoint |
# | field | field_current_archive_unblockable_gate_count | 0 | gates the existing archive can unblock alone |
# | field | field_critical_new_data_action_count | 5 | critical actions requiring new controlled data |
# | field | packet_missing_required_value_count | 44 | missing required values in controlled packet |
# | field | ready_for_collection_execution | True | whether the next action is collection execution |
# | field | ready_for_current_archive_field_fwi | False | whether current archive is sufficient for field FWI |
# | field | ready_for_field_3d_hpc | False | whether current field archive calls for 3D/HPC |

# %% [markdown]
# ## Recent Synthetic 2D Window
#
# ![Recent synthetic 2D phase coverage](../../../outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/recent_synthetic_2d_phase_coverage.png)
#
# *Figure: Output-directory coverage from run 1200 through the fixed-radius locking checkpoint, grouped by report-level phase.*
#
# | Phase | First | Last | Runs | Manifests |
# | --- | --- | --- | --- | --- |
# | 1200-1259 prior holistic tail and stop-point context | 1200 | 1259 | 60 | 59 |
# | 1260-1279 weak-exact confidence policy closure | 1260 | 1279 | 20 | 20 |
# | 1280-1293 ambiguity, objective, and reporting policy maps | 1280 | 1293 | 14 | 14 |
# | 1294-1307 close-spacing threshold probes and claim refresh | 1294 | 1307 | 14 | 14 |
# | 1308-1325 publication bundle and acquisition surfaces | 1308 | 1325 | 18 | 18 |
# | 1326-1338 local detector baselines and sampling boundary | 1326 | 1338 | 13 | 13 |
# | 1339-1343 fixed-radius controlled-prior diagnostics | 1339 | 1343 | 5 | 4 |
# | 1344-1356 matched source-count close-spacing probes | 1344 | 1356 | 13 | 13 |
# | 1357-1358 fixed-radius locking validation endpoint | 1357 | 1358 | 2 | 2 |

# %% [markdown]
# ## Synthetic 2D Endpoint: Fixed-Radius Locking Mechanism
#
# ![Fixed-radius synthetic endpoint](../../../outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/synthetic_fixed_radius_locking_endpoint.png)
#
# *Figure: Run 1357 leaves a 1 mm residual after the second pass. The CPU-side lock policy chooses target1=[250,90] with a 3.4 percent relative objective penalty and clears target2 truth geometry in run 1358.*
#
# Endpoint rows:
#
# | Run | Role | Initial Linf mm | Final Linf mm | Initial | Final | Truth |
# | --- | --- | --- | --- | --- | --- | --- |
# | 1357 | second pass before lock | 2 | 1 | x=[191,252,266], z=[90,89,91], r=[5,6,8] | x=[190,251,265], z=[90,89,91], r=[5,6,8] | x=[190,250,264], z=[90,90,90], r=[5,6,8] |
# | 1358 | target2 unlock after target1 lock | 2 | 0 | x=[190,250,266], z=[90,90,91], r=[5,6,8] | x=[190,250,264], z=[90,90,90], r=[5,6,8] | x=[190,250,264], z=[90,90,90], r=[5,6,8] |
#
# Lock-design decision:
#
# - Selected lock target: `1` at
#   `[x,z]=[250.0, 90.0]`.
# - Relative objective penalty: `0.034146`.
# - Downstream target2 truth clearance changed from
#   `-0.961595` mm to
#   `0.000000` mm.
# - Validation exact geometry recovered: `true`.
# - Guard maximum GPU/RAM during validation: `88.0` percent GPU,
#   `14.688` percent RAM.

# %% [markdown]
# ## Synthetic 2D Interpretation
#
# What is reportable:
#
# - The fixed-radius branch-locking result demonstrates a mechanism: a
#   truth-free near-tie lock can improve downstream geometry clearance on one
#   repaired target2 close14 branch.
# - The recent synthetic window strengthens the paper framing around
#   identifiability, ambiguity margins, and acquisition choices rather than a
#   generic claim that rebar detection is solved.
# - The current table pack preserves the claim boundary: point recovery,
#   strict confidence, near-tie ambiguity, and publication readiness should stay
#   separate.
#
# What remains blocked:
#
# - The validated lock is one branch, so it is not a deployable detector policy.
# - It does not justify broad GPU queues, detector-seeded FWI, or field transfer.
# - The target1/target2 close-spacing question still needs careful CPU-side
#   policy synthesis before any future narrow probe.

# %% [markdown]
# ## Full Field Experiment Chain
#
# ![Field phase coverage](../../../outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/field_phase_coverage_001_156.png)
#
# *Figure: All local GSSI field outputs through run 156, grouped by field-side logic phase.*
#
# | Phase | First | Last | Runs | Manifests |
# | --- | --- | --- | --- | --- |
# | 001-004 archive intake and initial status | 1 | 4 | 4 | 4 |
# | 005-017 phase-anchor and synthetic waveform probes | 6 | 17 | 12 | 12 |
# | 018-023 repeatability, alignment, and profile network | 18 | 23 | 6 | 6 |
# | 024-042 short-profile timing and content anchoring | 24 | 42 | 19 | 19 |
# | 043-058 corrected stacks and long-profile transfer | 43 | 58 | 16 | 16 |
# | 059-081 publication bundle, event tiers, and timing conflict | 59 | 81 | 23 | 23 |
# | 100-118 timing discriminants, cue support, and dimensionality | 82 | 118 | 38 | 38 |
# | 119-136 short-anchor inversion-readiness blockers | 119 | 136 | 18 | 18 |
# | 137-156 controlled 2D collection packet and critical path | 137 | 156 | 20 | 20 |

# %% [markdown]
# ## Field Critical Path
#
# ![Field gate critical path](../../../outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/field_critical_path_gates.png)
#
# *Figure: Run 156 shows seven acceptance gates, zero ready gates, and zero gates that can be unblocked by the existing archive alone.*
#
# Gate table:
#
# | Gate | Ready | Priority | Required Actions | Archive-Resolvable | New Data Actions | Missing Required | Critical Path |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | target_truth_controls | False | 1 | 1 | 0 | 1 | 9 | target_truth_geometry |
# | field_fwi_or_heavy_work | False | 1 | 3 | 0 | 3 | 21 | target_truth_geometry -> time_zero_reference -> amplitude_reference |
# | absolute_time_zero_references | False | 2 | 2 | 0 | 2 | 12 | time_zero_reference -> reference_registry |
# | amplitude_references | False | 3 | 2 | 0 | 2 | 12 | amplitude_reference -> reference_registry |
# | required_metadata_fields | False | 4 | 4 | 1 | 3 | 23 | profile_target_geometry -> acquisition_control_links -> session_metadata -> reference_registry |
# | cross_table_links | False | 4 | 3 | 0 | 3 | 21 | profile_target_geometry -> acquisition_control_links -> reference_registry |
# | short_repeat_redundancy | False | 4 | 2 | 0 | 2 | 15 | profile_target_geometry -> acquisition_control_links |

# %% [markdown]
# ## Field Collection Plan
#
# ![Controlled 2D field collection phase plan](../../../outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/field_controlled_collection_phase_plan.png)
#
# *Figure: The next field work is controlled 2D collection: target truth, time-zero and amplitude references, survey geometry, controlled repeats, and documentation overlay.*
#
# Collection phases:
#
# | Order | Phase | Blockers | Actions | Min Rows/Repeats | Missing Required | Gates Touched |
# | --- | --- | --- | --- | --- | --- | --- |
# | 1 | target_truth | target_truth_geometry | 1 | 1 | 9 | field_fwi_or_heavy_work,target_truth_controls |
# | 2 | references | time_zero_reference,amplitude_reference,reference_registry | 3 | 9 | 18 | absolute_time_zero_references,amplitude_references,cross_table_links,field_fwi_or_heavy_work,required_metadata_fields |
# | 3 | survey_geometry | profile_target_geometry | 1 | 1 | 6 | cross_table_links,required_metadata_fields,short_repeat_redundancy |
# | 4 | controlled_repeats | acquisition_control_links | 1 | 3 | 9 | cross_table_links,required_metadata_fields,short_repeat_redundancy |
# | 5 | session_metadata | session_metadata | 1 | 1 | 2 | required_metadata_fields |
#
# Critical actions:
#
# | Priority | Phase | Blocker | Planned IDs/Repeats | Minimum | Missing | Needs New Data | Archive Can Resolve |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | target_truth | target_truth_geometry | T_CONTROL_001 | 1 | 9 | True | False |
# | 2 | references | time_zero_reference | T0_REF_001,T0_REF_002,T0_REF_003 | 3 | 6 | True | False |
# | 3 | references | amplitude_reference | AMP_REF_001,AMP_REF_002,AMP_REF_003 | 3 | 6 | True | False |
# | 4 | survey_geometry | profile_target_geometry | P_CONTROL_001:T_CONTROL_001 | 1 | 6 | True | False |
# | 5 | controlled_repeats | acquisition_control_links | P_CONTROL_001:repeat1,P_CONTROL_001:repeat2,P_CONTROL_001:repeat3 | 3 | 9 | True | False |
# | 6 | session_metadata | session_metadata | planned_controlled_2d_session_001 | 1 | 2 | False | True |
# | 7 | references | reference_registry | AMP_REF_001,AMP_REF_002,AMP_REF_003,T0_REF_001,T0_REF_002,T0_REF_003 | 3 | 6 | True | False |

# %% [markdown]
# ## Publication Claim And Figure Inventory
#
# ![Claim and figure inventory](../../../outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/claim_figure_inventory.png)
#
# *Figure: Latest manuscript table pack: {int(context['table_summary'].get('claim_table_row_count', 0))} claim rows and {int(context['table_summary'].get('figure_inventory_row_count', 0))} figure rows, split between synthetic and field domains.*
#
# Selected high-signal figure rows:
#
# | Domain | Order | Figure | Role | Source Run | Status | Metric Summary |
# | --- | --- | --- | --- | --- | --- | --- |
# | field_2d | 1 | survey_geometry_boundary | field_guardrail_supplement | 015_gssi51600s_survey_geometry_audit | independent_2d_line_profiles | profile_count=4.0 |
# | field_2d | 2 | short_content_waveform_qc | field_primary_supplement | 035_gssi51600s_content_backed_waveform_panels | content_backed_waveform_visual_qc | min_abs_corr=0.8194940543205603 |
# | field_2d | 3 | short_supported_stack_intervals | field_primary_supplement | 049_gssi51600s_supported_interval_visual_qc | supported_interval_visual_qc_ready | min_corrected_interval_abs_corr=0.909284529790766 |
# | field_2d | 4 | long_pattern_visual_qc | field_guardrail_supplement | 057_gssi51600s_long_profile_pattern_visual_qc | long_profile_pattern_visual_qc_ready | min_shifted_abs_corr=0.889509154796464 |
# | field_2d | 5 | long_pattern_holdout_qc | field_guardrail_supplement | 058_gssi51600s_long_profile_pattern_holdout_qc | long_profile_pattern_holdout_qc_all_candidate_anchors_supported | repeat_limited_supported=2.0 |
# | field_2d | 6 | long_pattern_window_sensitivity | field_guardrail_supplement | 060_gssi51600s_long_profile_pattern_holdout_sensitivity | long_profile_pattern_holdout_sensitivity_all_candidate_anchors_all_windows_supported | all_window_supported_anchor_count=8.0 |
# | field_2d | 7 | long_pattern_width_sensitivity | field_guardrail_supplement | 061_gssi51600s_long_profile_pattern_holdout_width_sensitivity | long_profile_pattern_holdout_width_sensitivity_all_candidate_anchors_all_widths_supported | all_width_supported_anchor_count=8.0 |
# | field_2d | 8 | long_relaxed_phase_anchor_negative_qc | field_guardrail_supplement | 064_gssi51600s_long_profiles_relaxed_phase_anchor_audit | long_profile_relaxed_phase_anchor_low_snr_not_time_zero | low_snr_pick_count=10.0 |
# | field_2d | 9 | field_bandlimited_repeatability_qc | field_guardrail_supplement | 068_gssi51600s_field_bandlimited_repeatability_audit | field_bandlimited_repeatability_short_pair_supported_long_pattern_only | short_supported_band_count=4.0 |
# | field_2d | 10 | field_event_support_tiers | field_guardrail_supplement | 110_gssi51600s_field_event_support_tiers_post_timing_discriminant_hpc | field_event_support_tiers_timing_discriminant_hpc_2d_qc_ready_not_fwi | tier_row_count=11.0 |
# | field_2d | 11 | field_time_zero_uncertainty_budget | field_primary_supplement | 075_gssi51600s_field_time_zero_uncertainty_budget | field_time_zero_uncertainty_budget_short_pair_relative_qc_not_absolute | conservative_half_width_ns=0.058939096267190516 |
# | field_2d | 12 | field_time_zero_perturbation_sensitivity | field_primary_supplement | 078_gssi51600s_field_time_zero_perturbation_sensitivity | field_time_zero_ci_perturbation_stack_robust | bootstrap_ci_supported_count=9.0 |
# | field_2d | 13 | field_early_time_anchor_negative_qc | field_guardrail_supplement | 090_gssi51600s_field_early_time_anchor_audit | field_early_time_common_mode_not_content_time_zero | short_early_vs_content_delta_ns=0.12770137524557956 |
# | field_2d | 14 | field_timing_anchor_conflict | field_primary_supplement | 097_gssi51600s_field_timing_anchor_conflict_synthesis | field_timing_anchor_conflict_short_relative_not_absolute | early_vs_short_delta_half_widths=2.1666666666666687 |
#
# Selected claim rows:
#
# | Domain | Order | Area | Tier | Allowed Claim | Not Allowed |
# | --- | --- | --- | --- | --- | --- |
# | field_2d | 1 | field_geometry | field_supplement_guardrail | The local GSSI data are independent 2D line-profile QC evidence. | Do not treat the dataset as a recovered 3D survey grid without external layout metadata. |
# | field_2d | 2 | short_profile_timing | field_supplement_result | Use short 014/016 content-backed and supported-stack figures for relative timing/repeatability QC. | Do not claim absolute time-zero, cover depth, radius, or measured-data FWI from these panels. |
# | field_2d | 3 | long_profile_pattern | field_supplement_result | Use long 015/013 figures as pattern-only QC at the robust +0.06 ns shift. | Do not call the long-profile shift a phase anchor or transferable time-zero correction. |
# | field_2d | 4 | synthetic_separation | guardrail | Keep field QC and known-truth synthetic confidence policies separate. | Do not use field QC to relabel synthetic optimizer success or ambiguity tiers. |
# | field_2d | 5 | gpu_next_step | guardrail | No field GPU/FWI run is justified without external survey geometry or a new measured-data objective. | Do not launch field FWI/3D runs from this dataset alone. |
# | field_2d | 6 | long_profile_sensitivity | field_supplement_guardrail | The +0.06 ns long-profile pattern-only support survives the tested shallow time windows and anchor widths. | Do not convert sensitivity robustness into absolute phase-anchor, cover-depth, radius, 3D, or FWI claims. |
# | field_2d | 7 | long_relaxed_phase_anchor | field_supplement_guardrail | Use the relaxed long-profile phase-anchor audit as negative evidence: profile 013 candidates remain low-SNR and the long pair remains pattern-only QC. | Do not promote relaxed late-window picks to absolute time-zero, cover-depth, radius, 3D, or measured-data FWI evidence. |
# | field_2d | 8 | field_bandlimited_repeatability | field_supplement_guardrail | Use the band-limited repeatability audit to justify measured-field QC band choices for the short pair and pattern-only band support for the long pair. | Do not convert band-limited repeatability into absolute time-zero, cover-depth, radius, 3D, or measured-data FWI evidence. |
# | field_2d | 9 | field_event_support_tiers | field_supplement_guardrail | Use the event-support tier table to separate short-pair content-backed timing QC, long-pair pattern-only support, band-limited repeatability, and explicit FWI/3D blockers. | Do not convert event-support tiers into field radius, cover-depth, 3D, or measured-data FWI claims. |
# | field_2d | 10 | field_time_zero_uncertainty_budget | field_supplement_result | Use the relative time-zero uncertainty budget for short 014/016 QC, robustness accounting, and manuscript uncertainty bounds. | Do not convert the relative uncertainty budget into absolute time-zero, field FWI, 3D, radius, or cover-depth claims. |
# | field_2d | 11 | field_time_zero_perturbation_sensitivity | field_supplement_guardrail | Use the perturbation sensitivity audit to show that the short 014/016 B-scan QC remains supported under bootstrap-CI and conservative relative-offset perturbations. | Do not convert perturbation robustness into absolute time-zero, field FWI, 3D, radius, or cover-depth claims. |
# | field_2d | 12 | field_early_time_anchor_negative_qc | field_supplement_guardrail | Use the early-time median-trace audit as a negative control showing that common-mode/direct-wave alignment does not reproduce the content-backed short-pair offset. | Do not use the early direct/ringdown component as an absolute time-zero calibration, field FWI anchor, 3D inversion input, or replacement for content-backed timing. |
# | field_2d | 13 | field_timing_anchor_conflict | field_supplement_result | Use the timing-anchor conflict synthesis to keep short content-backed relative timing, early common-mode timing, and long pattern-only timing as separate scoped QC anchors. | Do not average or reconcile these anchors into absolute time-zero, cover-depth/radius recovery, field FWI, 3D inversion, or synthetic-policy relabeling. |
# | field_2d | 14 | field_timing_window_family_classification | field_supplement_result | Use the timing window-family classification to show that strict early windows are common-mode near-zero, short content windows support the relative correction envelope, and long shallow windows remain pattern-only. | Do not convert window-family separation into absolute time-zero, cover-depth/radius recovery, field FWI, 3D inversion, or synthetic-policy relabeling. |
# | field_2d | 15 | field_timing_discriminant_scorecard | field_supplement_guardrail | Use the timing-discriminant scorecard to report that early, short-content, raw/no-correction, and long-pattern timing windows are separable scoped QC evidence. | Do not convert the timing discriminants into absolute time-zero, cover-depth/radius recovery, field FWI, 3D inversion, or synthetic-policy relabeling. |
# | field_2d | 16 | field_cue_spacing_context | field_supplement_result | Use cue-spacing threshold sensitivity as measured-field context showing visible cues remain wider than the synthetic close-spacing stress scale. | Do not use measured cue spacing as known-truth rebar separation, synthetic resolution validation, calibrated cover-depth/radius evidence, field FWI, 3D inversion, or synthetic-policy relabeling. |

# %% [markdown]
# ## Source Artifacts And Reproducibility
#
# | Artifact | Path | Role |
# | --- | --- | --- |
# | Notebook report | docs/update/summary/014_2026-06-19_local_2d_field_holistic_report.ipynb | primary report artifact |
# | Generated report tables and figures | outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint | reproducible support directory |
# | Recent checkpoint summary | docs/update/summary/013_2026-06-19_local_2d_field_report_checkpoint.md | natural-checkpoint narrative |
# | Latest manuscript table pack | outputs/summary_tables/132_local_2d_field_manuscript_table_pack_post_fixed_radius_locking_validation | claim, figure, and metric inventory |
# | Synthetic fixed-radius lock design | outputs/summary_tables/130_local_2d_detector_fixed_radius_locking_policy_design | CPU-side lock policy |
# | Synthetic fixed-radius lock validation | outputs/summary_tables/131_local_2d_detector_fixed_radius_locking_policy_validation_post_unlock_probe | guarded unlock validation |
# | Field critical-path checkpoint | outputs/field_experiments/local_gssi_51600s_2026_06_09/156_gssi51600s_controlled_collection_critical_path | field natural checkpoint and next collection plan |
#
# Generated figure validation:
#
# | Figure | Width | Height | Unique Colors | Nonwhite Fraction |
# | --- | --- | --- | --- | --- |
# | outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/local_2d_field_scope_counts.png | 1890 | 936 | 520 | 0.453 |
# | outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/recent_synthetic_2d_phase_coverage.png | 1980 | 891 | 514 | 0.24 |
# | outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/field_phase_coverage_001_156.png | 1980 | 891 | 517 | 0.284 |
# | outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/synthetic_fixed_radius_locking_endpoint.png | 1980 | 864 | 489 | 0.385 |
# | outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/claim_figure_inventory.png | 2160 | 972 | 702 | 0.258 |
# | outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/field_critical_path_gates.png | 1980 | 972 | 532 | 0.337 |
# | outputs/summary_tables/133_local_2d_field_holistic_report_post_checkpoint/figures/field_controlled_collection_phase_plan.png | 1980 | 936 | 1238 | 0.16 |

# %% [markdown]
# ## Recommended Next Steps
#
# For the synthetic 2D side:
#
# - Write the report around acquisition-aware identifiability and ambiguity, not
#   around a universal rebar spacing limit.
# - Present run `1358` as a single-branch fixed-radius locking mechanism
#   validation, with run `1357` and summary tables `130-132` as the evidence
#   chain.
# - Keep broad GPU queues and detector-seeded FWI closed until CPU-side policy
#   synthesis identifies a narrow, falsifiable next probe.
#
# For the field side:
#
# - Treat the archive as independent 2D line profiles. Current field geometry:
#   `independent_2d_line_profiles`; 3D survey status:
#   `false`.
# - Execute the controlled 2D collection packet before attempting packet
#   acceptance, field FWI, heavy GPU work, or field-side HPC work.
# - Use run `156` as the resumption point because it states which gates are
#   blocked and which new measurements are required.
